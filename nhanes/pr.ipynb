# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_sas('/Users/jhli/Documents/umich/mdst/day1/P_DEMO.XPT')

# %%
df.shape
# Out:
# (15560, 29)

# %%
df['RIDAGEYR'].mean()
# Out:
# 33.742480719794344

# %%
df[df['RIDRETH1'] == 4.0]
# Out:
#            SEQN  SDDSRVYR  RIDSTATR  RIAGENDR      RIDAGEYR  RIDAGEMN  \
# 7      109270.0      66.0       2.0       2.0  1.100000e+01       NaN
# 13     109276.0      66.0       2.0       1.0  5.397605e-79       2.0
# 22     109285.0      66.0       2.0       1.0  1.600000e+01       NaN
# 27     109290.0      66.0       2.0       2.0  6.800000e+01       NaN
# 33     109296.0      66.0       2.0       1.0  1.000000e+01       NaN
# ...         ...       ...       ...       ...           ...       ...
# 15551  124814.0      66.0       2.0       1.0  6.400000e+01       NaN
# 15552  124815.0      66.0       2.0       1.0  5.200000e+01       NaN
# 15555  124818.0      66.0       2.0       1.0  4.000000e+01       NaN
# 15556  124819.0      66.0       2.0       1.0  2.000000e+00       NaN
# 15558  124821.0      66.0       2.0       1.0  6.300000e+01       NaN
#
#        RIDRETH1  RIDRETH3  RIDEXMON  DMDBORN4  ...  FIAINTRP  MIALANG  \
# ...

# %%
race = df.groupby("RIDRETH3")[

# %%
df.plot.scatter(x = race, y = df[], alpha=.6)
